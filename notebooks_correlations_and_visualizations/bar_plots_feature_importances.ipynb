# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
my_colors = ['#668B8B', '#CDAF95', '#CDB5CD', '#CAE1FF']
sns.set_style("whitegrid")
sns.set_palette(my_colors )
pd.options.display.max_colwidth=100

# %%
age = pd.read_pickle('../data/feature_importances/age.pkl')
age = age.head(10)
gender = pd.read_pickle('../data/feature_importances/gender.pkl')
gender = gender.head(10)

# %%
age['Feature']
# Out:
# 0                               different_activity_types_4
# 1             steps__fft_coefficient__attr_angle__coeff_24
# 2                  sleep_duration__fourier_entropy__bins_2
# 3                            steps__autocorrelation__lag_7
# 4    sleep_duration__fft_coefficient__attr_angle__coeff_28
# 5            sleep_duration__ar_coefficient__coeff_9__k_10
# 6    sleep_duration__fft_coefficient__attr_angle__coeff_22
# 7                         sleep_duration__count_below_mean
# 8                  stress_score__ratio_beyond_r_sigma__r_5
# 9                      steps__symmetry_looking__r_0.05_1.0
# Name: Feature, dtype: object

# %%
age = age.replace(["different_activity_types_4", "steps__fft_coefficient__attr_angle__coeff_24", "sleep_duration__fourier_entropy__bins_2", 
                   "steps__autocorrelation__lag_7", "sleep_duration__fft_coefficient__attr_angle__coeff_28", 
                   "sleep_duration__ar_coefficient__coeff_9__k_10",  "sleep_duration__fft_coefficient__attr_angle__coeff_22", 
                   "sleep_duration__count_below_mean", "stress_score__ratio_beyond_r_sigma__r_5", "steps__symmetry_looking__r_0.05_1.0"], ["activity_types", "steps__fft_24", 
                                           "sleep_fourier_entropy", "steps_autocorrelation", 
                                           "sleep__fft_28", "sleep__ar_coeff_9",
                                           "sleep__fft_22", "sleep_below_mean",
                                           "stress_ratio", " steps__symmetry"])

# %%
fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
age.plot.barh(x='Feature', y='Value', title='Age Prediction', color='#668B8B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/age_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/age_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/age_feature_importance.pdf",bbox_inches='tight')

# %%
gender['Feature']
# Out:
# 0                                                different_activity_types_2
# 1                               steps__fft_coefficient__attr_angle__coeff_6
# 2                                                different_activity_types_4
# 3                              steps__fft_coefficient__attr_angle__coeff_26
# 4                                steps__fft_coefficient__attr_abs__coeff_20
# 5    sleep_duration__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_min
# 6       sleep_duration__large_standard_deviation__r_0.15000000000000002_1.0
# 7                              steps__fft_coefficient__attr_angle__coeff_10
# 8                       stress_score__fft_coefficient__attr_angle__coeff_29
# 9                              steps__fft_coefficient__attr_angle__coeff_15
# Name: Feature, dtype: object

# %%
gender = gender.replace(["different_activity_types_2", "steps__fft_coefficient__attr_angle__coeff_6", "different_activity_types_4",
                         "steps__fft_coefficient__attr_angle__coeff_26", "steps__fft_coefficient__attr_abs__coeff_20", 
                         "sleep_duration__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_min", 
                         "sleep_duration__large_standard_deviation__r_0.15000000000000002_1.0", "steps__fft_coefficient__attr_angle__coeff_10",
                         "stress_score__fft_coefficient__attr_angle__coeff_29", "steps__fft_coefficient__attr_angle__coeff_15"], ["activity_types2", "steps__fft_coeff_6", "activity_types4",
                         "steps_fft_coeff_26", "steps_fft_coeff_20", 
                         "sleep_agg_linear_trend", 
                         "sleep_large_std", "steps_fft_coeff_10",
                         "stress_fft_coeff_29", "steps_fft_coeff_15"])

# %%
fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
gender.plot.barh(x='Feature', y='Value', title='Gender Prediction', color='#668B8B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/gender_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/gender_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/gender_feature_importance.pdf",bbox_inches='tight')

# %%
fitness = pd.read_pickle('../data/feature_importances/fitness.pkl')
fitness = fitness.head(10)

# %%
fitness['Feature']
# Out:
# 0                                   lightly_active_minutes
# 1                             minutes_below_default_zone_1
# 2                                                month_sin
# 3                                              endWeek_sin
# 4                                                isp_index
# 5                                minutes_in_default_zone_1
# 6                                             Steps_hour11
# 7    sleep_duration__fft_coefficient__attr_angle__coeff_29
# 8                                             Steps_hour16
# 9                               different_activity_types_4
# Name: Feature, dtype: object

# %%
fitness = fitness.replace(["lightly_active_minutes", "minutes_below_default_zone_1", "month_sin","endWeek_sin", "isp_index", 
                         "minutes_in_default_zone_1", "Steps_hour11", "sleep_duration__fft_coefficient__attr_angle__coeff_29", "Steps_hour16",
                         "different_activity_types_4"], ["lightly_active_mins", "mins_below_default_zone_1", "month_sin","endWeek_sin", "isp_index", 
                         "mins_in_default_zone_1", "Steps_hour11", "sleep_fft_coeff_29", "Steps_hour16",
                         "activity_types4"])

# %%
fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
fitness.plot.barh(x='Feature', y='Value', title='Fitness Prediction', color='#CDAF95')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/fitness_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/fitness_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/fitness_feature_importance.pdf",bbox_inches='tight')

# %%
agreeableness = pd.read_pickle('../data/feature_importances/agreeableness.pkl')
agreeableness = agreeableness.head(10)
intellect = pd.read_pickle('../data/feature_importances/intellect.pkl')
intellect = intellect.head(10)
conscientiousness = pd.read_pickle('../data/feature_importances/conscientiousness.pkl')
conscientiousness = conscientiousness.head(10)
extraversion = pd.read_pickle('../data/feature_importances/extraversion.pkl')
extraversion = extraversion.head(10)
stability = pd.read_pickle('../data/feature_importances/stability.pkl')
stability = stability.head(10)

# %%
agreeableness['Feature']
# Out:
# 0                             steps__has_duplicate_min_1.0
# 1             steps__fft_coefficient__attr_angle__coeff_21
# 2             steps__fft_coefficient__attr_angle__coeff_17
# 3                                       mode_startTime_cos
# 4    sleep_duration__fft_coefficient__attr_angle__coeff_19
# 5             steps__fft_coefficient__attr_angle__coeff_34
# 6      stress_score__fft_coefficient__attr_angle__coeff_41
# 7             steps__fft_coefficient__attr_angle__coeff_56
# 8              steps__fft_coefficient__attr_imag__coeff_17
# 9      sleep_duration__large_standard_deviation__r_0.2_1.0
# Name: Feature, dtype: object

# %%
agreeableness = agreeableness.replace(["steps__has_duplicate_min_1.0", "steps__fft_coefficient__attr_angle__coeff_21",
                                       "steps__fft_coefficient__attr_angle__coeff_17", "mode_startTime_cos", 
                                       "sleep_duration__fft_coefficient__attr_angle__coeff_19", "steps__fft_coefficient__attr_angle__coeff_34",
                                       "stress_score__fft_coefficient__attr_angle__coeff_41", "steps__fft_coefficient__attr_angle__coeff_56",
                                       "steps__fft_coefficient__attr_imag__coeff_17", "sleep_duration__large_standard_deviation__r_0.2_1.0"], ["steps_duplicate", "steps__fft_coeff_21",
                                       "steps__fft_coeff_17", "mode_startTime_cos", 
                                       "sleep_fft_coeff_19", "steps__fft_coeff_34",
                                       "stress_sfft_coeff_41", "steps__fft_coeff_56",
                                       "steps__fft_coeff_17", "sleep_large_std"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
agreeableness.plot.barh(x='Feature', y='Value', title='Agreeableness Prediction', color='#5D478B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/agreeableness_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/agreeableness_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/agreeableness_feature_importance.pdf",bbox_inches='tight')

# %%
intellect['Feature']
# Out:
# 0      sleep_density_coeff_5
# 1             sleep_symmetry
# 2             mode_startTime
# 3         stress_fft_coeff_8
# 4         sleep_fft_coeff_21
# 5         sleep_fft_coeff_12
# 6        stress_fft_coeff_20
# 7    steps__agg_linear_trend
# 8        steps__energy_ratio
# 9         steps__fft_coeff26
# Name: Feature, dtype: object

# %%
intellect = intellect.replace(["sleep_duration__spkt_welch_density__coeff_5", "sleep_duration__symmetry_looking__r_0.05_0.0",
                               "mode_startTime_1.0", "stress_score__fft_coefficient__attr_angle__coeff_8",
                               "sleep_duration__fft_coefficient__attr_real__coeff_21", "sleep_duration__fft_coefficient__attr_angle__coeff_12",
                               "stress_score__fft_coefficient__attr_angle__coeff_20", 
                               "steps__agg_linear_trend__attr_rvalue__chunk_len_50__f_agg_mean",
                               "steps__energy_ratio_by_chunks__num_segments_10__segment_focus_8",
                               "steps__fft_coefficient__attr_real__coeff_26"], ["sleep_density_coeff_5", "sleep_symmetry",
                               "mode_startTime", "stress_fft_coeff_8",
                               "sleep_fft_coeff_21", "sleep_fft_coeff_12",
                               "stress_fft_coeff_20", 
                               "steps__agg_linear_trend",
                               "steps__energy_ratio",
                               "steps__fft_coeff26"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
intellect.plot.barh(x='Feature', y='Value', title='Intellect Prediction', color='#5D478B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/intellect_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/intellect_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/intellect_feature_importance.pdf",bbox_inches='tight')

# %%
conscientiousness['Feature']
# Out:
# 0    activity_types2
# 1         bmi_Normal
# 2    activity_types5
# 3         startTime0
# 4         endTime_15
# 5     mode_endTime_6
# 6          bmi_Obese
# 7          endTime_7
# 8      startTime_cos
# 9    activity_types1
# Name: Feature, dtype: object

# %%
conscientiousness = conscientiousness.replace(["different_activity_types_2", "bmi_Normal", "different_activity_types_5", "mode_startTime_0.0",
                                       "mode_endTime_15.0", "mode_endTime_6.0", "bmi_Obese", "mode_endTime_7.0", "mode_startTime_cos",
                                       "different_activity_types_1"], ["activity_types2", "bmi_Normal", "activity_types5", "startTime0",
                                       "endTime_15", "mode_endTime_6", "bmi_Obese", "endTime_7", "startTime_cos",
                                       "activity_types1"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
conscientiousness.plot.barh(x='Feature', y='Value', title='Conscientiousness Prediction', color='#5D478B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/conscientiousness_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/conscientiousness_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/conscientiousness_feature_importance.pdf",bbox_inches='tight')

# %%
extraversion['Feature']
# Out:
# 0                different_badges2
# 1                      sleep_coeff
# 2                        steps_min
# 3                        endTime_8
# 4                  activity_types3
# 5    steps_time_reversal_asymmetry
# 6             sleepfourier_entropy
# 7               steps_fft_coeff_45
# 8            steps_autocorrelation
# 9                steps_fft_coeff_9
# Name: Feature, dtype: object

# %%
extraversion = extraversion.replace(["different_badge_types_2", "sleep_duration__cwt_coefficients__coeff_6__w_2__widths_(2 5 10 20)",
                                     "steps__minimum", "mode_endTime_8.0", "different_activity_types_3", 
                                     "steps__time_reversal_asymmetry_statistic__lag_1", "sleep_duration__fourier_entropy__bins_2",
                                     "steps__fft_coefficient__attr_real__coeff_45", "steps__autocorrelation__lag_7",
                                     "steps__fft_coefficient__attr_angle__coeff_9"], ["different_badges2", "sleep_coeff",
                                     "steps_min", "endTime_8", "activity_types3", 
                                     "steps_time_reversal_asymmetry", "sleepfourier_entropy",
                                     "steps_fft_coeff_45", "steps_autocorrelation",
                                     "steps_fft_coeff_9"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
extraversion.plot.barh(x='Feature', y='Value', title='Extraversion Prediction', color='#5D478B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/extraversion_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/extraversion_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/extraversion_feature_importance.pdf",bbox_inches='tight')

# %%
stability['Feature']
# Out:
# 0      steps__fft_coeff_18
# 1          activity_types1
# 2       steps__fft_coeff_2
# 3           sleep_symmetry
# 4                      age
# 5       sleep_fft_coeff_55
# 6              steps_coeff
# 7    sleep_autocorrelation
# 8       steps_coefficients
# 9      steps__energy_ratio
# Name: Feature, dtype: object

# %%
stability = stability.replace(["steps__fft_coefficient__attr_angle__coeff_18", "different_activity_types_1",
                               "steps__fft_coefficient__attr_angle__coeff_2", "sleep_duration__symmetry_looking__r_0.05_0.0",
                               "age_0.0", "sleep_duration__fft_coefficient__attr_angle__coeff_55", 
                               "steps__cwt_coefficients__coeff_14__w_2__widths_(2 5 10 20)",
                               "sleep_duration__autocorrelation__lag_9", "steps__cwt_coefficients__coeff_10__w_2__widths_(2 5 10 20)",
                               "steps__energy_ratio_by_chunks__num_segments_10__segment_focus_1"], ["steps__fft_coeff_18", "activity_types1",
                               "steps__fft_coeff_2", "sleep_symmetry",
                               "age", "sleep_fft_coeff_55", 
                               "steps_coeff",
                               "sleep_autocorrelation", "steps_coefficients",
                               "steps__energy_ratio"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
stability.plot.barh(x='Feature', y='Value', title='Stability Prediction', color='#5D478B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/stability_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/stability_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/stability_feature_importance.pdf",bbox_inches='tight')

# %%
sema = pd.read_pickle('../data/feature_importances/sema.pkl')
sema = sema.head(10)
stai = pd.read_pickle('../data/feature_importances/stai.pkl')
stai = stai.head(10)
panas = pd.read_pickle('../data/feature_importances/panas.pkl')
panas = panas.head(8)

# %%
sema['Feature']
# Out:
# 0          minutesAsleep
# 1       sleep_deep_ratio
# 2    very_active_minutes
# 3         is_weekend_0.0
# 4         is_holiday_1.0
# 5          startWeek_cos
# 6            endHour_cos
# 7    LIFETIME_FLOORS_0.0
# 8       DAILY_FLOORS_1.0
# 9               Swim_0.0
# Name: Feature, dtype: object

# %%
sema = sema.replace(["minutesAsleep", "sleep_deep_ratio", "very_active_minutes", "is_weekend_0.0", "is_holiday_1.0",
                     "startWeek_cos", "endHour_cos", "LIFETIME_FLOORS_0.0", "DAILY_FLOORS_1.0", "Swim_0.0"], ["minutesAsleep", "sleep_deep_ratio", 
                                                                                                              "very_active_mins", 
                                                                                                              "is_weekend", "is_holiday",
                     "startWeek_cos", "endHour_cos", "LIFETIME_FLOORS", "DAILY_FLOORS", "Swim"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
sema.plot.barh(x='Feature', y='Value', title='Sema Prediction', color='#CD9B9B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/sema_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/sema_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/sema_feature_importance.pdf",bbox_inches='tight')

# %%
stai['Feature']
# Out:
# 0                                                            endWeek_sin
# 1                                                 lightly_active_minutes
# 2                                    steps__symmetry_looking__r_0.05_1.0
# 3                                                          startWeek_cos
# 4                                                    nightly_temperature
# 5                                                        DAILY_STEPS_1.0
# 6                                                               week_sin
# 7                   sleep_duration__fft_coefficient__attr_angle__coeff_6
# 8                                                       mode_endTime_7.0
# 9    sleep_duration__large_standard_deviation__r_0.15000000000000002_0.0
# Name: Feature, dtype: object

# %%
stai = stai.replace(["endWeek_sin", "lightly_active_minutes", "steps__symmetry_looking__r_0.05_1.0", "startWeek_cos",
                     "nightly_temperature", "DAILY_STEPS_1.0", "week_sin", "sleep_duration__fft_coefficient__attr_angle__coeff_6", 
                     "mode_endTime_7.0", "sleep_duration__large_standard_deviation__r_0.15000000000000002_0.0"], ["endWeek_sin", "lightly_active_mins", "steps__symmetry", "startWeek_cos",
                     "nightly_temperature", "DAILY_STEPS", "week_sin", "sleep_fft_coeff_6", 
                     "mode_endTime", "sleep_large_std"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
stai.plot.barh(x='Feature', y='Value', title='Stai Prediction', color='#CD9B9B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/stai_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/stai_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/stai_feature_importance.pdf",bbox_inches='tight')

# %%
panas['Feature']
# Out:
# 0              Yoga/Pilates_0.0
# 1              Martial Arts_0.0
# 2    GOAL_BASED_WEIGHT_LOSS_0.0
# 3                  Bootcamp_0.0
# 4          Interval Workout_0.0
# 5             stress_quantile_1
# 6         LIFETIME_DISTANCE_0.0
# 7                      Swim_0.0
# Name: Feature, dtype: object

# %%
panas = panas.replace(["Yoga/Pilates_0.0", "Martial Arts_0.0", "GOAL_BASED_WEIGHT_LOSS_0.0", "Bootcamp_0.0",
                       "Interval Workout_0.0", "stress_quantile_1", "LIFETIME_DISTANCE_0.0", "Swim_0.0"], ["Yoga/Pilates", "Martial Arts", "GOAL_BASED_WEIGHT_LOSS", "Bootcamp",
                       "Interval Workout", "stress_quantile", "LIFETIME_DISTANCE", "Swim"])

fig = plt.gcf()
fig.set_size_inches(10, 10)
sns.set(font_scale = 2)
panas.plot.barh(x='Feature', y='Value', title='Panas Prediction', color='#CD9B9B')
plt.xlabel('Relative Importance')
plt.legend().set_visible(False)
plt.savefig("visualizations/panas_feature_importance.png",bbox_inches='tight')
plt.savefig("visualizations/panas_feature_importance.eps",bbox_inches='tight')
plt.savefig("visualizations/panas_feature_importance.pdf",bbox_inches='tight')
